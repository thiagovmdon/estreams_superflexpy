# %%
import pandas as pd
import datetime as datetime
import matplotlib.pyplot as plt
import numpy as np
import spotpy
import time
import os
import tqdm as tqdm

# %%
# Set the directory:
#os.chdir(PATH)

# %%
path_estreams = r'C:\Users\nascimth\Documents\Thiago\Eawag\Python\Scripts\estreams_part_b\data\EStreams'

# %%
network_estreams = pd.read_csv(path_estreams+'\streamflow_gauges/estreams_gauging_stations.csv', encoding='utf-8')
network_estreams.set_index("basin_id", inplace = True)

# Convert 'date_column' and 'time_column' to datetime
network_estreams['start_date'] = pd.to_datetime(network_estreams['start_date'])
network_estreams['end_date'] = pd.to_datetime(network_estreams['end_date'])

network_estreams
# Out:
#          gauge_id           gauge_name gauge_country gauge_provider  \
# basin_id
# AT000001   200014                Bangs            AT        AT_EHYD
# AT000002   200048  Schruns (Vonbunweg)            AT        AT_EHYD
# AT000003   231662        Loruens-Aeule            AT        AT_EHYD
# AT000004   200592    Kloesterle (OEBB)            AT        AT_EHYD
# AT000005   200097  Buers (Bruecke L82)            AT        AT_EHYD
# ...           ...                  ...           ...            ...
# UAGR0017  6682300          BASHTANOVKA            UA        UA_GRDC
# UAGR0018  6682500                YALTA            UA        UA_GRDC
# UAGR0019  6683010           PIONERSKOE            UA        UA_GRDC
# UAGR0020  6683200               TOKMAK            UA        UA_GRDC
# UAGR0021  6683300          NOVOSELOVKA            UA        UA_GRDC
#
#               river   lon_snap   lat_snap        lon        lat elevation  \
# basin_id
# AT000001      Rhein   9.534835  47.273748   9.534835  47.273748       420
# AT000002       Litz   9.913677  47.080301   9.913677  47.080301       673
# AT000003        Ill   9.847765  47.132821   9.847765  47.132821       579
# AT000004     Alfenz  10.061843  47.128994  10.061843  47.128994      1014
# AT000005     Alvier   9.802668  47.150770   9.802668  47.150770       564
# ...             ...        ...        ...        ...        ...       ...
# UAGR0017      KACHA  33.894739  44.691884  33.900000  44.683333       NaN
# UAGR0018  DERE-KIOY  34.166667  44.500000  34.166667  44.500000        16
# UAGR0019     SALHYR  34.199841  44.887685  34.200000  44.883333       307
# UAGR0020     TOKMAK  35.705833  47.251389  35.705833  47.251389       NaN
# UAGR0021     KRYNKA  38.144722  48.153333  38.144722  48.153333       118
#
#           ...  num_continuous_days  num_days_gaps  num_days_reliable  \
# basin_id  ...
# AT000001  ...                 9497            0.0                0.0
# AT000002  ...                23103            0.0                0.0
# AT000003  ...                13513            0.0                0.0
# AT000004  ...                 8765            0.0                0.0
# AT000005  ...                10957            0.0                0.0
# ...       ...                  ...            ...                ...
# UAGR0017  ...                 3652            0.0                0.0
# UAGR0018  ...                 3652            0.0                0.0
# UAGR0019  ...                 3652            0.0                0.0
# UAGR0020  ...                 3652            0.0                0.0
# UAGR0021  ...                 3652            0.0                0.0
#
#           num_days_noflag num_days_suspect gauge_flag  duplicated_suspect  \
# basin_id
# AT000001           9497.0              0.0          B        ['CH000197']
# AT000002          23103.0              0.0          B        ['CH000221']
# AT000003          13513.0              0.0          B        ['CH000215']
# AT000004           8765.0              0.0          B        ['CH000227']
# AT000005          10957.0              0.0          B        ['CH000214']
# ...                   ...              ...        ...                 ...
# UAGR0017           3652.0              0.0          B                 NaN
# UAGR0018           3652.0              0.0          B                 NaN
# UAGR0019           3652.0              0.0          B                 NaN
# UAGR0020           3652.0              0.0          B                 NaN
# UAGR0021           3652.0              0.0          B                 NaN
#
#           watershed_group  gauges_upstream  \
# basin_id
# AT000001                1               16
# AT000002                1                1
# AT000003                1                2
# AT000004                1                1
# AT000005                1                3
# ...                   ...              ...
# UAGR0017             1988                1
# UAGR0018             1989                1
# UAGR0019             1990                1
# UAGR0020             1991                1
# UAGR0021             1992                1
#
#                                           nested_catchments
# basin_id
# AT000001  ['AT000001', 'CH000010', 'CH000046', 'CH000048...
# AT000002                                       ['AT000002']
# AT000003               ['AT000002', 'AT000003', 'CH000221']
# AT000004                                       ['AT000004']
# AT000005                           ['AT000005', 'CH000214']
# ...                                                     ...
# UAGR0017                                       ['UAGR0017']
# UAGR0018                                       ['UAGR0018']
# UAGR0019                                       ['UAGR0019']
# UAGR0020                                       ['UAGR0020']
# UAGR0021                                       ['UAGR0021']
#
# [17130 rows x 29 columns]

# %%
# Daily streamflow time-series
timeseries_estreams = pd.read_csv(r"C:\Users\nascimth\Documents\Thiago\Eawag\Python\Scripts\estreams_part_b\data\EStreams\streamflow\estreams_timeseries_streamflow.csv", index_col=0)
timeseries_estreams.index = pd.to_datetime(timeseries_estreams.index)
timeseries_estreams.index.name = "dates"
timeseries_estreams
# Out:
#             AT000001  AT000002  AT000003  AT000004  AT000005  AT000006  \
# dates
# 1900-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1900-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 1900-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 1900-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 1900-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-27       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-12-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-12-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-12-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-12-31       NaN       NaN       NaN       NaN       NaN       NaN
#
#             AT000007  AT000008  AT000009  AT000010  ...  UAGR0012  UAGR0013  \
# dates                                               ...
# 1900-01-01       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1900-01-02       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1900-01-03       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1900-01-04       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1900-01-05       NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-12-27       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2023-12-28       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2023-12-29       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2023-12-30       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2023-12-31       NaN       NaN       NaN       NaN  ...       NaN       NaN
#
#             UAGR0014  UAGR0015  UAGR0016  UAGR0017  UAGR0018  UAGR0019  \
# dates
# 1900-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1900-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 1900-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 1900-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 1900-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-27       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-12-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-12-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-12-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-12-31       NaN       NaN       NaN       NaN       NaN       NaN
#
#             UAGR0020  UAGR0021
# dates
# 1900-01-01       NaN       NaN
# 1900-01-02       NaN       NaN
# 1900-01-03       NaN       NaN
# 1900-01-04       NaN       NaN
# 1900-01-05       NaN       NaN
# ...              ...       ...
# 2023-12-27       NaN       NaN
# 2023-12-28       NaN       NaN
# 2023-12-29       NaN       NaN
# 2023-12-30       NaN       NaN
# 2023-12-31       NaN       NaN
#
# [45290 rows x 17130 columns]

# %%
for basin_id in tqdm.tqdm(network_estreams.index):
    data = pd.read_csv(path_estreams+"/meteorology/estreams_meteorology_"+basin_id+".csv", index_col=0)

    data["q_mean"] = timeseries_estreams[basin_id]
    data.to_csv(r"C:\Users\nascimth\Documents\Thiago\Eawag\Python\Data\data"+"\estreams_timeseries_"+basin_id+".csv")

data
# Out:
#   0%|          | 0/17130 [00:00<?, ?it/s]
# 100%|██████████| 17130/17130 [1:14:11<00:00,  3.85it/s]
#             p_mean  t_mean  t_min  t_max  sp_mean  rh_mean  ws_mean  swr_mean  \
# date
# 1950-01-01    0.00  -17.14 -21.06 -11.69      NaN      NaN      NaN       NaN
# 1950-01-02    0.00  -18.19 -21.16 -13.75      NaN      NaN      NaN       NaN
# 1950-01-03    1.78   -8.29 -19.11  -1.86      NaN      NaN      NaN       NaN
# 1950-01-04    0.00   -4.71  -6.80  -1.94      NaN      NaN      NaN       NaN
# 1950-01-05    2.63  -11.19 -14.94  -5.25      NaN      NaN      NaN       NaN
# ...            ...     ...    ...    ...      ...      ...      ...       ...
# 2023-06-26   16.22   19.38  15.85  21.81      NaN      NaN     2.12       NaN
# 2023-06-27    0.00   18.85  15.70  20.51      NaN      NaN     2.18       NaN
# 2023-06-28    1.15   17.72  14.87  22.67      NaN      NaN     1.99       NaN
# 2023-06-29    7.30   17.19  15.53  20.72      NaN      NaN     1.87       NaN
# 2023-06-30    5.39   16.64  13.27  20.40      NaN      NaN     2.09       NaN
#
#             pet_mean  q_mean
# date
# 1950-01-01      0.02     NaN
# 1950-01-02      0.00     NaN
# 1950-01-03      0.32     NaN
# 1950-01-04      0.24     NaN
# 1950-01-05      0.17     NaN
# ...              ...     ...
# 2023-06-26      3.55     NaN
# 2023-06-27      3.14     NaN
# 2023-06-28      3.87     NaN
# 2023-06-29      3.10     NaN
# 2023-06-30      3.58     NaN
#
# [26844 rows x 10 columns]
